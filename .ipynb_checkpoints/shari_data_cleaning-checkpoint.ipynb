# %%
import numpy as np
import pandas as pd
import pyreadstat

# %%
df.to_csv("dataset2021/data/df.csv")

# %%
wave1 = pd.read_spss("dataset2021/data/data/W1 Merged Data/Wave.1_Data/Merge/Wave1_20170906.sav")
wave1

# %%
wave2 = pd.read_spss("dataset2021/data/data/W2 Merged Data/2w-3rd_release_all/merge/Wave2_20170724.sav")
wave2
# Out:
#         country  idnumber level3                        q1               q2  \
# 0         Japan      11.0  Urban  So so (not good nor bad)       Much worse
# 1         Japan      12.0  Urban                      Good  A little better
# 2         Japan      23.0  Urban                      Good  A little better
# 3         Japan     100.0  Urban                       Bad   About the same
# 4         Japan     107.0  Urban                      Good  A little better
# ...         ...       ...    ...                       ...              ...
# 19793  Malaysia    1214.0  Urban                      Good  A little better
# 19794  Malaysia    1215.0  Urban                      Good  A little better
# 19795  Malaysia    1216.0  Urban                      Good      Much better
# 19796  Malaysia    1217.0  Urban  So so (not good nor bad)  A little better
# 19797  Malaysia    1218.0  Urban                       Bad   A little worse
#
# ...
